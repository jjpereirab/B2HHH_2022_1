# %%
from root_pandas import read_root
import pandas as pd
from matplotlib.pyplot import *
from numpy import *

pd.set_option('display.max_columns', None)
rcParams["figure.figsize"] = (8,5)
# Out:
# Welcome to JupyROOT 6.24/06

# %% [markdown]
# Momentum function

# %%
Pi_m = 139.57039 # MeV
K_m  = 493.677   # MeV

def momentum(data, hadron):
    p2 = getattr(data, hadron + "_PX")**2 + getattr(data, hadron + "_PY")**2 + getattr(data, hadron + "_PZ")**2
    p = sqrt(p2)
    return p

# %% [markdown]
# Preselection for all kaons

# %%
prob_ka = 0.5
prob_pi = 0.5

preselection_Muon1 = "H1_isMuon == 0 & H2_isMuon == 0 & H3_isMuon == 0"
preselection_Pion1 = "H1_ProbPi < {0} & H2_ProbPi < {0} & H3_ProbPi < {0}".format(prob_pi)
preselection_Kaon1 = "H1_ProbK > {0} & H2_ProbK > {0} & H3_ProbK > {0}".format(prob_ka)

preselection_kaons = preselection_Muon1 + " & " + preselection_Pion1 + " & " + preselection_Kaon1

# %% [markdown]
# --------------

# %% [markdown]
# # Magnet up only

# %%
magnetUp = read_root("Data/B2HHH_MagnetUp.root")

# %%
magnetUp_kaons = magnetUp.query(preselection_kaons)
magnetUp_kaons.shape[0]
# Out:
# 9717

# %%
nbin = 30
p1, p2, p3 = (momentum(magnetUp_kaons, "H1"), momentum(magnetUp_kaons, "H2"), momentum(magnetUp_kaons, "H3"))

fig, axs = subplots(1,3, figsize = (20,5))
p1.hist(bins = nbin , ax = axs[0])
p2.hist(bins = nbin , ax = axs[1])
p3.hist(bins = nbin , ax = axs[2])

suptitle("kaons momentum", fontsize = 20)
# Out:
# Text(0.5, 0.98, 'kaons momentum')

# %%
c1up, c2up, c3up = (magnetUp_kaons.H1_Charge, magnetUp_kaons.H2_Charge, magnetUp_kaons.H3_Charge)

fig, axs = subplots(1,3, figsize = (20,5))
c1up.hist(bins = nbin , ax = axs[0])
c2up.hist(bins = nbin , ax = axs[1])
c3up.hist(bins = nbin , ax = axs[2])

suptitle("charges", fontsize = 20)
# Out:
# Text(0.5, 0.98, 'charges')

# %%
(c1up + c2up + c3up).value_counts()
# Out:
#  1    5002
# -1    4715
# dtype: int64

# %%
magnetUp_kaons[(c1up + c2up + c3up) == 1]
# Out:
#          B_FlightDistance  B_VertexChi2        H1_PX        H1_PY  \
# 325             10.428140      4.056947 -4168.055539  -704.953919
# 539             33.591307      2.220242  1295.910334   -61.956920
# 588             16.531858     11.593388  1493.048615  1944.600925
# 1086             4.102797     11.321708  -236.694032   843.809179
# 1236             3.509346      5.739399   123.873807   856.290459
# ...                   ...           ...          ...          ...
# 3417173          8.057556      9.598444 -2375.956014  -377.782055
# 3417500         11.229602      1.274428  1692.069768  2217.627656
# 3418607         21.122374      0.093512   657.258601 -1715.773444
# 3418621         10.086018      2.420546   -66.223341 -1333.016070
# 3418959         18.420011      3.523767 -3300.862201  -183.677783
#
#                 H1_PZ  H1_ProbK  H1_ProbPi  H1_Charge    H1_IPChi2  H1_isMuon  \
# 325      24548.766576  0.771199   0.051726         -1  1002.657075          0
# ...

# %% [markdown]
# --------------------

# %% [markdown]
# # Magnet Down only

# %%
magnetDown = read_root("Data/B2HHH_MagnetDown.root")

# %%
magnetDown_kaons = magnetDown.query(preselection_kaons)
magnetDown_kaons.shape[0]
# Out:
# 14178

# %%
nbin = 30
p1, p2, p3 = (momentum(magnetDown_kaons, "H1"), momentum(magnetDown_kaons, "H2"), momentum(magnetDown_kaons, "H3"))

fig, axs = subplots(1,3, figsize = (20,5))
p1.hist(bins = nbin , ax = axs[0])
p2.hist(bins = nbin , ax = axs[1])
p3.hist(bins = nbin , ax = axs[2])

suptitle("kaons momenta (magnetDown)", fontsize = 20)
# Out:
# Text(0.5, 0.98, 'kaons momenta (magnetDown)')

# %%
c1Down, c2Down, c3Down = (magnetDown_kaons.H1_Charge, magnetDown_kaons.H2_Charge, magnetDown_kaons.H3_Charge)

fig, axs = subplots(1,3, figsize = (20,5))
c1Down.hist(bins = nbin , ax = axs[0])
c2Down.hist(bins = nbin , ax = axs[1])
c3Down.hist(bins = nbin , ax = axs[2])

suptitle("charges", fontsize = 20)
# Out:
# Text(0.5, 0.98, 'charges')

# %%
(c1Down + c2Down + c3Down).value_counts()
# Out:
#  1    7388
# -1    6790
# dtype: int64

# %%
magnetDown_kaons[(c1Down + c2Down + c3Down) == 1]
# Out:
#          B_FlightDistance  B_VertexChi2        H1_PX        H1_PY  \
# 679              6.888037      8.426947  1207.753798   -84.290958
# 1751             9.100733      4.113123 -2007.925735 -2555.080382
# 1894            11.077374      2.360357  1408.170513 -1372.864558
# 2608            15.875883      1.656760  2336.165388  4166.002188
# 2945             7.960260      9.528332 -1740.175238  1060.634895
# ...                   ...           ...          ...          ...
# 5132979          7.145459      2.532950   352.051358  -932.583303
# 5133371          7.890939      3.588902  3638.905811  1693.988077
# 5134452         31.090393      3.318735  -868.888215  -429.546948
# 5134870         24.390861      3.469873  -889.296699   431.478857
# 5135290          6.202372      5.247019   497.978128  -500.453009
#
#                 H1_PZ  H1_ProbK  H1_ProbPi  H1_Charge    H1_IPChi2  H1_isMuon  \
# 679      10399.473702  0.902219   0.041574         -1   998.424410          0
# ...

# %% [markdown]
# --------------------

# %% [markdown]
# # Both datasets

# %%
df = read_root(["Data/B2HHH_MagnetUp.root","Data/B2HHH_MagnetDown.root"])

# %%
pd.set_option('display.max_columns', None)
print(df.columns)
df
# Out:
# Index(['B_FlightDistance', 'B_VertexChi2', 'H1_PX', 'H1_PY', 'H1_PZ',
#        'H1_ProbK', 'H1_ProbPi', 'H1_Charge', 'H1_IPChi2', 'H1_isMuon', 'H2_PX',
#        'H2_PY', 'H2_PZ', 'H2_ProbK', 'H2_ProbPi', 'H2_Charge', 'H2_IPChi2',
#        'H2_isMuon', 'H3_PX', 'H3_PY', 'H3_PZ', 'H3_ProbK', 'H3_ProbPi',
#        'H3_Charge', 'H3_IPChi2', 'H3_isMuon'],
#       dtype='object')
#          B_FlightDistance  B_VertexChi2        H1_PX        H1_PY  \
# 0               11.241923      3.870827  1038.634354  4933.332660
# 1               14.429881     10.294972  -318.157696 -6407.683029
# 2               12.489381      9.303937   -97.802248   199.043666
# 3                9.420983      4.829225  -527.819868  -651.630894
# 4                7.362626      5.922298   -61.928986   552.828398
# ...                   ...           ...          ...          ...
# 8556113          3.433852      1.182499  2606.910839  -945.534339
# 8556114          3.406146      6.125212  2606.910839  -945.534339
# ...

# %% [markdown]
# -------------------------

# %% [markdown]
# #### Flight distance (mm)
#
# The distance between the collision point, where the B meson is created, and the decay point of the B meson, where the three final state particles are created, is the flight distance of the B meson. [Ref: information list](Background-Information-Notebooks/EventData.ipynb)
#
#
# ### Ref paper says "...decay vertex displacement from any PV greater than 3 mm". Is it referring to this one parameter?

# %%
print(df.B_FlightDistance.describe())
df.B_FlightDistance.hist(bins=100); title("Flight distance", fontsize = 20)
yscale("log")
# Out:
# count    8.556118e+06
# mean     1.304660e+01
# std      2.144604e+01
# min      3.000001e+00
# 25%      5.195601e+00
# 50%      8.002593e+00
# 75%      1.371131e+01
# max      2.621654e+03
# Name: B_FlightDistance, dtype: float64

# %% [markdown]
# #### $\chi^2$ statistical measure of how compatible the three tracks (final state particles) are from having come from a common point.
# A large value (greater than 1) suggests that the tracks do not really come from a common point, and hence it is more likely that they are not from a real B meson decay. [Ref: information list](Background-Information-Notebooks/EventData.ipynb)
#
# ### Ref paper says "...decay vertex $\chi^2 < 12$". Is it referring to this one parameter?

# %%
print(df.B_VertexChi2.describe())
df.B_VertexChi2.hist(bins=100); title("B vertex Chi2", fontsize = 20) ;  show()
# Out:
# count    8.556118e+06
# mean     5.430332e+00
# std      3.327471e+00
# min      1.264907e-04
# 25%      2.552722e+00
# 50%      5.065350e+00
# 75%      8.153070e+00
# max      1.200000e+01
# Name: B_VertexChi2, dtype: float64

# %% [markdown]
# #### The impact parameter is defined as the perpendicular distance between the path of the particle and the proton-proton collision vertex.
# The three final state tracks come from the B meson decay point and hence should not point back to the collision vertex. Most of the tracks in an event are produced at the collision point and thus if a track does point back to the collision vertex it is an indication that it might not come from the B meson decay. The χ2 is a measure of how compatible this track is from coming from the collision vertex taking the uncertainties into account. [Ref: information list](Background-Information-Notebooks/EventData.ipynb)
#
# ### Ref paper says "...$χ_{IP}^{2} < 10$ (defined by projecting the B candidate trajectory backwards from its decay vertex)". Is it referring to this one parameter?

# %%
print(df.H1_IPChi2.describe())
nbin = 100
ip1, ip2, ip3 = (df.H1_IPChi2, df.H2_IPChi2, df.H3_IPChi2)

fig, axs = subplots(1,3, figsize = (20,5))
ip1.hist(bins = nbin , ax = axs[0]);  axs[0].set_yscale("log"); #axs[0].set_title("asd")
ip2.hist(bins = nbin , ax = axs[1]);  axs[1].set_yscale("log")
ip3.hist(bins = nbin , ax = axs[2]);  axs[2].set_yscale("log")

suptitle("IP Chi2", fontsize = 20)
# Out:
# count    8.556118e+06
# mean     7.834023e+02
# std      3.205236e+03
# min      1.000002e+00
# 25%      5.308578e+00
# 50%      1.065561e+02
# 75%      7.240711e+02
# max      1.743161e+06
# Name: H1_IPChi2, dtype: float64
# Text(0.5, 0.98, 'IP Chi2')

# %% [markdown]
# ----------------------

# %% [markdown]
# # Momenta

# %%
kaons = df.query(preselection_kaons)

nbin = 30
p1, p2, p3 = (momentum(kaons, "H1"), momentum(kaons, "H2"), momentum(kaons, "H3"))

fig, axs = subplots(1,3, figsize = (20,5))
p1.hist(bins = nbin , ax = axs[0])
p2.hist(bins = nbin , ax = axs[1])
p3.hist(bins = nbin , ax = axs[2])

suptitle("kaons", fontsize = 20)
#axs[0].set_yscale("log")
# Out:
# Text(0.5, 0.98, 'kaons')
