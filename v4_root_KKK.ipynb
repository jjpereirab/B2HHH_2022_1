// %% [markdown]
// # <div style="text-align:center"> $B^{\pm} \xrightarrow{} K^+ K^- K^{\pm}$ </div>

// %%
#include <iostream>
#include <string>
#include <stdio.h>

TChain *B2HHH = new TChain("DecayTree");
B2HHH->Add("data/B2HHH_MagnetUp.root");
B2HHH->Add("data/B2HHH_MagnetDown.root");

B2HHH->Print()
// Out:
// ******************************************************************************
// *Chain   :DecayTree : data/B2HHH_MagnetUp.root                               *
// ******************************************************************************
// ******************************************************************************
// *Tree    :DecayTree : Tree continaing data for B- --> h-h+h- decays          *
// *Entries :  3420295 : Total =       629522894 bytes  File  Size =  444718406 *
// *        :          : Tree compression factor =   1.42                       *
// ******************************************************************************
// *Br    0 :B_FlightDistance : B_FlightDistance/D                              *
// *Entries :  3420295 : Total  Size=   27370973 bytes  File Size  =   24630500 *
// *Baskets :       72 : Basket Size=    1873408 bytes  Compression=   1.05     *
// *............................................................................*
// *Br    1 :B_VertexChi2 : B_VertexChi2/D                                      *
// *Entries :  3420295 : Total  Size=   27370661 bytes  File Size  =   24812127 *
// *Baskets :       72 : Basket Size=    1873408 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    2 :H1_PX     : H1_PX/D                                                *
// *Entries :  3420295 : Total  Size=   27370014 bytes  File Size  =   23539994 *
// *Baskets :       71 : Basket Size=    1872896 bytes  Compression=   1.10     *
// *............................................................................*
// *Br    3 :H1_PY     : H1_PY/D                                                *
// *Entries :  3420295 : Total  Size=   27370014 bytes  File Size  =   23540929 *
// *Baskets :       71 : Basket Size=    1872896 bytes  Compression=   1.10     *
// *............................................................................*
// *Br    4 :H1_PZ     : H1_PZ/D                                                *
// *Entries :  3420295 : Total  Size=   27370014 bytes  File Size  =   23414290 *
// *Baskets :       71 : Basket Size=    1872896 bytes  Compression=   1.11     *
// *............................................................................*
// *Br    5 :H1_ProbK  : H1_ProbK/D                                             *
// *Entries :  3420295 : Total  Size=   27370349 bytes  File Size  =   13771090 *
// *Baskets :       72 : Basket Size=    1872896 bytes  Compression=   1.88     *
// *............................................................................*
// *Br    6 :H1_ProbPi : H1_ProbPi/D                                            *
// *Entries :  3420295 : Total  Size=   27370427 bytes  File Size  =   14100649 *
// *Baskets :       72 : Basket Size=    1873408 bytes  Compression=   1.84     *
// *............................................................................*
// *Br    7 :H1_Charge : H1_Charge/I                                            *
// *Entries :  3420295 : Total  Size=   13686194 bytes  File Size  =    1346631 *
// *Baskets :       43 : Basket Size=     936448 bytes  Compression=   9.63     *
// *............................................................................*
// *Br    8 :H1_IPChi2 : H1_IPChi2/D                                            *
// *Entries :  3420295 : Total  Size=   27370427 bytes  File Size  =   23421345 *
// *Baskets :       72 : Basket Size=    1873408 bytes  Compression=   1.11     *
// *............................................................................*
// *Br    9 :H1_isMuon : H1_isMuon/I                                            *
// *Entries :  3420295 : Total  Size=   13686194 bytes  File Size  =     932161 *
// *Baskets :       43 : Basket Size=     936448 bytes  Compression=  13.91     *
// *............................................................................*
// *Br   10 :H2_PX     : H2_PX/D                                                *
// *Entries :  3420295 : Total  Size=   27370014 bytes  File Size  =   24093289 *
// *Baskets :       71 : Basket Size=    1872896 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   11 :H2_PY     : H2_PY/D                                                *
// *Entries :  3420295 : Total  Size=   27370014 bytes  File Size  =   24093979 *
// *Baskets :       71 : Basket Size=    1872896 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   12 :H2_PZ     : H2_PZ/D                                                *
// *Entries :  3420295 : Total  Size=   27370014 bytes  File Size  =   23854633 *
// *Baskets :       71 : Basket Size=    1872896 bytes  Compression=   1.09     *
// *............................................................................*
// *Br   13 :H2_ProbK  : H2_ProbK/D                                             *
// *Entries :  3420295 : Total  Size=   27370349 bytes  File Size  =   14072949 *
// *Baskets :       72 : Basket Size=    1872896 bytes  Compression=   1.84     *
// *............................................................................*
// *Br   14 :H2_ProbPi : H2_ProbPi/D                                            *
// *Entries :  3420295 : Total  Size=   27370427 bytes  File Size  =   14351987 *
// *Baskets :       72 : Basket Size=    1873408 bytes  Compression=   1.81     *
// *............................................................................*
// *Br   15 :H2_Charge : H2_Charge/I                                            *
// *Entries :  3420295 : Total  Size=   13686194 bytes  File Size  =    1349984 *
// *Baskets :       43 : Basket Size=     936448 bytes  Compression=   9.60     *
// *............................................................................*
// *Br   16 :H2_IPChi2 : H2_IPChi2/D                                            *
// *Entries :  3420295 : Total  Size=   27370427 bytes  File Size  =   23988756 *
// *Baskets :       72 : Basket Size=    1873408 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   17 :H2_isMuon : H2_isMuon/I                                            *
// *Entries :  3420295 : Total  Size=   13686194 bytes  File Size  =     694361 *
// *Baskets :       43 : Basket Size=     936448 bytes  Compression=  18.67     *
// *............................................................................*
// *Br   18 :H3_PX     : H3_PX/D                                                *
// *Entries :  3420295 : Total  Size=   27370014 bytes  File Size  =   22914016 *
// *Baskets :       71 : Basket Size=    1872896 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   19 :H3_PY     : H3_PY/D                                                *
// *Entries :  3420295 : Total  Size=   27370014 bytes  File Size  =   22912473 *
// *Baskets :       71 : Basket Size=    1872896 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   20 :H3_PZ     : H3_PZ/D                                                *
// *Entries :  3420295 : Total  Size=   27370014 bytes  File Size  =   22848257 *
// *Baskets :       71 : Basket Size=    1872896 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   21 :H3_ProbK  : H3_ProbK/D                                             *
// *Entries :  3420295 : Total  Size=   27370349 bytes  File Size  =   13721578 *
// *Baskets :       72 : Basket Size=    1872896 bytes  Compression=   1.89     *
// *............................................................................*
// *Br   22 :H3_ProbPi : H3_ProbPi/D                                            *
// *Entries :  3420295 : Total  Size=   27370427 bytes  File Size  =   13848957 *
// *Baskets :       72 : Basket Size=    1873408 bytes  Compression=   1.87     *
// *............................................................................*
// *Br   23 :H3_Charge : H3_Charge/I                                            *
// *Entries :  3420295 : Total  Size=   13686194 bytes  File Size  =    1349984 *
// *Baskets :       43 : Basket Size=     936448 bytes  Compression=   9.60     *
// *............................................................................*
// *Br   24 :H3_IPChi2 : H3_IPChi2/D                                            *
// *Entries :  3420295 : Total  Size=   27370427 bytes  File Size  =   22759894 *
// *Baskets :       72 : Basket Size=    1873408 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   25 :H3_isMuon : H3_isMuon/I                                            *
// *Entries :  3420295 : Total  Size=   13686194 bytes  File Size  =     854197 *
// *Baskets :       43 : Basket Size=     936448 bytes  Compression=  15.18     *
// *............................................................................*
// ******************************************************************************
// *Chain   :DecayTree : data/B2HHH_MagnetDown.root                             *
// ******************************************************************************
// ******************************************************************************
// *Tree    :DecayTree : Tree continaing data for B- --> h-h+h- decays          *
// *Entries :  5135823 : Total =       945201654 bytes  File  Size =  666480138 *
// *        :          : Tree compression factor =   1.42                       *
// ******************************************************************************
// *Br    0 :B_FlightDistance : B_FlightDistance/D                              *
// *Entries :  5135823 : Total  Size=   41096093 bytes  File Size  =   38701498 *
// *Baskets :       80 : Basket Size=    1873408 bytes  Compression=   1.05     *
// *............................................................................*
// *Br    1 :B_VertexChi2 : B_VertexChi2/D                                      *
// *Entries :  5135823 : Total  Size=   41095749 bytes  File Size  =   38985222 *
// *Baskets :       80 : Basket Size=    1873408 bytes  Compression=   1.04     *
// *............................................................................*
// *Br    2 :H1_PX     : H1_PX/D                                                *
// *Entries :  5135823 : Total  Size=   41095046 bytes  File Size  =   36920206 *
// *Baskets :       79 : Basket Size=    1872896 bytes  Compression=   1.10     *
// *............................................................................*
// *Br    3 :H1_PY     : H1_PY/D                                                *
// *Entries :  5135823 : Total  Size=   41095046 bytes  File Size  =   36921744 *
// *Baskets :       79 : Basket Size=    1872896 bytes  Compression=   1.10     *
// *............................................................................*
// *Br    4 :H1_PZ     : H1_PZ/D                                                *
// *Entries :  5135823 : Total  Size=   41095046 bytes  File Size  =   36720770 *
// *Baskets :       79 : Basket Size=    1872896 bytes  Compression=   1.11     *
// *............................................................................*
// *Br    5 :H1_ProbK  : H1_ProbK/D                                             *
// *Entries :  5135823 : Total  Size=   41095405 bytes  File Size  =   21614904 *
// *Baskets :       80 : Basket Size=    1872896 bytes  Compression=   1.88     *
// *............................................................................*
// *Br    6 :H1_ProbPi : H1_ProbPi/D                                            *
// *Entries :  5135823 : Total  Size=   41095491 bytes  File Size  =   22114417 *
// *Baskets :       80 : Basket Size=    1873408 bytes  Compression=   1.84     *
// *............................................................................*
// *Br    7 :H1_Charge : H1_Charge/I                                            *
// *Entries :  5135823 : Total  Size=   20549146 bytes  File Size  =    2115157 *
// *Baskets :       51 : Basket Size=     936448 bytes  Compression=   9.63     *
// *............................................................................*
// *Br    8 :H1_IPChi2 : H1_IPChi2/D                                            *
// *Entries :  5135823 : Total  Size=   41095491 bytes  File Size  =   36736055 *
// *Baskets :       80 : Basket Size=    1873408 bytes  Compression=   1.11     *
// *............................................................................*
// *Br    9 :H1_isMuon : H1_isMuon/I                                            *
// *Entries :  5135823 : Total  Size=   20549146 bytes  File Size  =    1429890 *
// *Baskets :       51 : Basket Size=     936448 bytes  Compression=  14.25     *
// *............................................................................*
// *Br   10 :H2_PX     : H2_PX/D                                                *
// *Entries :  5135823 : Total  Size=   41095046 bytes  File Size  =   37820468 *
// *Baskets :       79 : Basket Size=    1872896 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   11 :H2_PY     : H2_PY/D                                                *
// *Entries :  5135823 : Total  Size=   41095046 bytes  File Size  =   37822250 *
// *Baskets :       79 : Basket Size=    1872896 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   12 :H2_PZ     : H2_PZ/D                                                *
// *Entries :  5135823 : Total  Size=   41095046 bytes  File Size  =   37447244 *
// *Baskets :       79 : Basket Size=    1872896 bytes  Compression=   1.09     *
// *............................................................................*
// *Br   13 :H2_ProbK  : H2_ProbK/D                                             *
// *Entries :  5135823 : Total  Size=   41095405 bytes  File Size  =   22081344 *
// *Baskets :       80 : Basket Size=    1872896 bytes  Compression=   1.84     *
// *............................................................................*
// *Br   14 :H2_ProbPi : H2_ProbPi/D                                            *
// *Entries :  5135823 : Total  Size=   41095491 bytes  File Size  =   22518595 *
// *Baskets :       80 : Basket Size=    1873408 bytes  Compression=   1.81     *
// *............................................................................*
// *Br   15 :H2_Charge : H2_Charge/I                                            *
// *Entries :  5135823 : Total  Size=   20549146 bytes  File Size  =    2119863 *
// *Baskets :       51 : Basket Size=     936448 bytes  Compression=   9.61     *
// *............................................................................*
// *Br   16 :H2_IPChi2 : H2_IPChi2/D                                            *
// *Entries :  5135823 : Total  Size=   41095491 bytes  File Size  =   37658938 *
// *Baskets :       80 : Basket Size=    1873408 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   17 :H2_isMuon : H2_isMuon/I                                            *
// *Entries :  5135823 : Total  Size=   20549146 bytes  File Size  =    1062531 *
// *Baskets :       51 : Basket Size=     936448 bytes  Compression=  19.17     *
// *............................................................................*
// *Br   18 :H3_PX     : H3_PX/D                                                *
// *Entries :  5135823 : Total  Size=   41095046 bytes  File Size  =   35895514 *
// *Baskets :       79 : Basket Size=    1872896 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   19 :H3_PY     : H3_PY/D                                                *
// *Entries :  5135823 : Total  Size=   41095046 bytes  File Size  =   35892520 *
// *Baskets :       79 : Basket Size=    1872896 bytes  Compression=   1.13     *
// *............................................................................*
// *Br   20 :H3_PZ     : H3_PZ/D                                                *
// *Entries :  5135823 : Total  Size=   41095046 bytes  File Size  =   35789178 *
// *Baskets :       79 : Basket Size=    1872896 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   21 :H3_ProbK  : H3_ProbK/D                                             *
// *Entries :  5135823 : Total  Size=   41095405 bytes  File Size  =   21497632 *
// *Baskets :       80 : Basket Size=    1872896 bytes  Compression=   1.89     *
// *............................................................................*
// *Br   22 :H3_ProbPi : H3_ProbPi/D                                            *
// *Entries :  5135823 : Total  Size=   41095491 bytes  File Size  =   21697575 *
// *Baskets :       80 : Basket Size=    1873408 bytes  Compression=   1.88     *
// *............................................................................*
// *Br   23 :H3_Charge : H3_Charge/I                                            *
// *Entries :  5135823 : Total  Size=   20549146 bytes  File Size  =    2119863 *
// *Baskets :       51 : Basket Size=     936448 bytes  Compression=   9.61     *
// *............................................................................*
// *Br   24 :H3_IPChi2 : H3_IPChi2/D                                            *
// *Entries :  5135823 : Total  Size=   41095491 bytes  File Size  =   35654822 *
// *Baskets :       80 : Basket Size=    1873408 bytes  Compression=   1.14     *
// *............................................................................*
// *Br   25 :H3_isMuon : H3_isMuon/I                                            *
// *Entries :  5135823 : Total  Size=   20549146 bytes  File Size  =    1311241 *
// *Baskets :       51 : Basket Size=     936448 bytes  Compression=  15.53     *
// *............................................................................*

// %% [markdown]
// ### Declaring and defining the dataset variables

// %%
Double_t B_FlightDistance;          Double_t B_VertexChi2;

Int_t H1_isMuon;         Int_t H2_isMuon;          Int_t H3_isMuon;
Int_t H1_Charge;         Int_t H2_Charge;          Int_t H3_Charge;
Double_t H1_IPChi2;      Double_t H2_IPChi2;       Double_t H3_IPChi2;
Double_t H1_PX;          Double_t H2_PX;           Double_t H3_PX;
Double_t H1_PY;          Double_t H2_PY;           Double_t H3_PY;
Double_t H1_PZ;          Double_t H2_PZ;           Double_t H3_PZ;
Double_t H1_ProbPi;      Double_t H2_ProbPi;       Double_t H3_ProbPi;
Double_t H1_ProbK;       Double_t H2_ProbK;        Double_t H3_ProbK;

B2HHH->SetBranchAddress("B_FlightDistance", &B_FlightDistance);    B2HHH->SetBranchAddress("B_VertexChi2", &B_VertexChi2);

B2HHH->SetBranchAddress("H1_isMuon", &H1_isMuon);     B2HHH->SetBranchAddress("H2_isMuon", &H2_isMuon);     B2HHH->SetBranchAddress("H3_isMuon", &H3_isMuon);
B2HHH->SetBranchAddress("H1_Charge", &H1_Charge);     B2HHH->SetBranchAddress("H2_Charge", &H2_Charge);     B2HHH->SetBranchAddress("H3_Charge", &H3_Charge);
B2HHH->SetBranchAddress("H1_IPChi2", &H1_IPChi2);     B2HHH->SetBranchAddress("H2_IPChi2", &H2_IPChi2);     B2HHH->SetBranchAddress("H3_IPChi2", &H3_IPChi2);
B2HHH->SetBranchAddress("H1_PX", &H1_PX);             B2HHH->SetBranchAddress("H2_PX", &H2_PX);             B2HHH->SetBranchAddress("H3_PX", &H3_PX);
B2HHH->SetBranchAddress("H1_PY", &H1_PY);             B2HHH->SetBranchAddress("H2_PY", &H2_PY);             B2HHH->SetBranchAddress("H3_PY", &H3_PY);
B2HHH->SetBranchAddress("H1_PZ", &H1_PZ);             B2HHH->SetBranchAddress("H2_PZ", &H2_PZ);             B2HHH->SetBranchAddress("H3_PZ", &H3_PZ);
B2HHH->SetBranchAddress("H1_ProbPi", &H1_ProbPi);     B2HHH->SetBranchAddress("H2_ProbPi", &H2_ProbPi);     B2HHH->SetBranchAddress("H3_ProbPi", &H3_ProbPi);
B2HHH->SetBranchAddress("H1_ProbK", &H1_ProbK);       B2HHH->SetBranchAddress("H2_ProbK", &H2_ProbK);       B2HHH->SetBranchAddress("H3_ProbK", &H3_ProbK);

//---------OTHER DEFINITIONS

B_m = 5279.38; // B meson mass in MeV
double Pi_m = 139.57039; // MeV
double K_m  = 493.677;   // MeV
double D0m = 1864.84;    // MeV

float prob_pi = 0.5;
float prob_ka = 0.5;

int nentries, nbytes, i;
nentries = (Int_t)B2HHH->GetEntries();

// %% [markdown]
// ------------------

// %% [markdown]
// # Dalitz plots

// %%
double min_prob_ka = 0.8;  double max_prob_pi = 0.2;

// Dalitz plot bins
int dpxbins = 10;
int dpybins = 14;

TH2F *whole = new TH2F("whole","whole sym; Mlow^{2}; Mhigh^{2}",dpxbins,0,25, dpybins, 0, 35);

TH1F *h_Mlowplus = new TH1F("h_Mlowplus","m_{low}^{2}; m(GeV); Events",80,0,15);
TH1F *h_Mlowplus_focused = new TH1F("h_Mlowplus_focused","m_{low}^{2}; m(GeV); Events",20,0.8,2.8);
TH1F *h_Mhighplus = new TH1F("h_Mhighplus","m_{high}^{2}; m(GeV); Events",80,0,35);
TH2F *h_Bplus = new TH2F("h_Bplus","B^{+}; m12^{2}; m13^{2}",20,0,35, 20, 0, 35);
TH2F *h_Bplus_sym = new TH2F("h_Bplus_sym","B^{+} sym; Mlow^{2}; Mhigh^{2}",dpxbins,0,25, dpybins, 0, 35);

TH1F *h_Mlowminus = new TH1F("h_Mlowminus","m_{low}^{2}; m(GeV); Events",80,0,15);
TH1F *h_Mlowminus_focused = new TH1F("h_Mlowminus_focused","m_{low}^{2}; m(GeV); Events",20,0.8,2.8);
TH1F *h_Mhighminus = new TH1F("h_Mhighminus","m_{high}^{2}; m(GeV); Events",80,0,35);
TH2F *h_Bminus = new TH2F("h_Bminus","B^{-}; m12^{2}; m13^{2}",20,0,35, 20, 0, 35);
TH2F *h_Bminus_sym = new TH2F("h_Bminus_sym","B^{-} sym; Mlow^{2}; Mhigh^{2}",dpxbins,0,25, dpybins, 0, 35);
// Out:
// Warning in <TROOT::Append>: Replacing existing TH1: whole (Potential memory leak).
// Warning in <TROOT::Append>: Replacing existing TH1: h_Mlowplus (Potential memory leak).
// Warning in <TROOT::Append>: Replacing existing TH1: h_Mlowplus_focused (Potential memory leak).
// Warning in <TROOT::Append>: Replacing existing TH1: h_Mhighplus (Potential memory leak).
// Warning in <TROOT::Append>: Replacing existing TH1: h_Bplus (Potential memory leak).
// Warning in <TROOT::Append>: Replacing existing TH1: h_Bplus_sym (Potential memory leak).
// Warning in <TROOT::Append>: Replacing existing TH1: h_Mlowminus (Potential memory leak).
// Warning in <TROOT::Append>: Replacing existing TH1: h_Mlowminus_focused (Potential memory leak).
// Warning in <TROOT::Append>: Replacing existing TH1: h_Mhighminus (Potential memory leak).
// Warning in <TROOT::Append>: Replacing existing TH1: h_Bminus (Potential memory leak).
// Warning in <TROOT::Append>: Replacing existing TH1: h_Bminus_sym (Potential memory leak).

// %%
for (i = 0; i < nentries; i++)
{
    nbytes = B2HHH->GetEntry(i); 
    
    if(H1_isMuon == 1 || H2_isMuon == 1 || H3_isMuon == 1) continue;
    if(H1_ProbK < min_prob_ka || H2_ProbK < min_prob_ka || H3_ProbK < min_prob_ka) continue;
    if(H1_ProbPi  > max_prob_pi || H2_ProbPi  > max_prob_pi || H3_ProbPi  > max_prob_pi) continue;
    
    // DEFINING AND FEEDING TLORENTZ VECTORS
    TLorentzVector Kaon1  = TLorentzVector();   Kaon1.SetXYZM(H1_PX, H1_PY, H1_PZ,K_m);  
    TLorentzVector Kaon2  = TLorentzVector();   Kaon2.SetXYZM(H2_PX, H2_PY, H2_PZ,K_m);  
    TLorentzVector Kaon3  = TLorentzVector();   Kaon3.SetXYZM(H3_PX, H3_PY, H3_PZ,K_m);   
    
    // WORKING OUT THE RANDOMIZATION
    TRandom2 *rand = new TRandom2(i);          int r = rand->Binomial(1,0.5);
    TLorentzVector *vec_array = new TLorentzVector[2];
    vec_array[0] = Kaon2;      vec_array[1] = Kaon3;
    
    // 2-BODY INVARIANT MASSES (NOTE RANDOMNESS)
    double M12 = (Kaon1 + vec_array[r]).M();     double M13 = (Kaon1 + vec_array[1-r]).M();
    
    double PT = (Kaon1 + Kaon2 + Kaon3).Pt();
    double Bmass = (Kaon1 + Kaon2 + Kaon3).M();
    
    if(Bmass < B_m + 50 && Bmass > B_m - 50 && PT > 1700) { // B Pt and Mass cuts
    
        if( (M12 < D0m - 30. || M12 > D0m + 30.) && (M13 < D0m - 30. || M13 > D0m + 30.) ){ // D0 exclusion

            if(H1_Charge == -1) { 
                h_Bplus->Fill(M12*M12/1e6,M13*M13/1e6);
                // Mlow and Mhigh separation
                if(M12 > M13){ 
                    h_Mlowplus->Fill(M13*M13/1e6);   h_Mhighplus->Fill(M12*M12/1e6);
                    h_Bplus_sym->Fill(M13*M13/1e6,M12*M12/1e6); 
                    whole->Fill(M13*M13/1e6,M12*M12/1e6); 
                    if(M12*M12 < 15e6) {h_Mlowplus_focused->Fill(M13*M13/1e6);}
                }
                else{
                    h_Mlowplus->Fill(M12*M12/1e6);   h_Mhighplus->Fill(M13*M13/1e6);
                    h_Bplus_sym->Fill(M12*M12/1e6,M13*M13/1e6); 
                    whole->Fill(M12*M12/1e6,M13*M13/1e6); 
                    if(M13*M13 < 15e6) {h_Mlowplus_focused->Fill(M12*M12/1e6);}
                }
            }

            if(H1_Charge == 1) { 
                h_Bminus->Fill(M12*M12/1e6,M13*M13/1e6);
                // Mlow and Mhigh separation
                if(M12 > M13){
                    h_Mlowminus->Fill(M13*M13/1e6);   h_Mhighminus->Fill(M12*M12/1e6);
                    h_Bminus_sym->Fill(M13*M13/1e6,M12*M12/1e6); 
                    whole->Fill(M13*M13/1e6,M12*M12/1e6); 
                    if(M12*M12 < 15e6) {h_Mlowminus_focused->Fill(M13*M13/1e6);}
                }
                else{
                    h_Mlowminus->Fill(M12*M12/1e6);   h_Mhighminus->Fill(M13*M13/1e6);
                    h_Bminus_sym->Fill(M12*M12/1e6,M13*M13/1e6); 
                    whole->Fill(M12*M12/1e6,M13*M13/1e6); 
                    if(M13*M13 < 15e6) {h_Mlowminus_focused->Fill(M12*M12/1e6);}
                }
            }
        }
    }
}

// %%
for (i = 0; i < nentries; i++)
{
    nbytes = B2HHH->GetEntry(i); 
    
    if(H1_isMuon == 1 || H2_isMuon == 1 || H3_isMuon == 1) continue;
    if(H1_ProbK < min_prob_ka || H2_ProbK < min_prob_ka || H3_ProbK < min_prob_ka) continue;
    if(H1_ProbPi  > max_prob_pi || H2_ProbPi  > max_prob_pi || H3_ProbPi  > max_prob_pi) continue;
    
    // DEFINING AND FEEDING TLORENTZ VECTORS
    TLorentzVector Kaon1  = TLorentzVector();   Kaon1.SetXYZM(H1_PX, H1_PY, H1_PZ,K_m);  
    TLorentzVector Kaon2  = TLorentzVector();   Kaon2.SetXYZM(H2_PX, H2_PY, H2_PZ,K_m);  
    TLorentzVector Kaon3  = TLorentzVector();   Kaon3.SetXYZM(H3_PX, H3_PY, H3_PZ,K_m);   
    
    // WORKING OUT THE RANDOMIZATION
    TRandom2 *rand = new TRandom2(i);          int r = rand->Binomial(1,0.5);
    TLorentzVector *vec_array = new TLorentzVector[2];
    vec_array[0] = Kaon2;      vec_array[1] = Kaon3;
    
    // 2-BODY INVARIANT MASSES (NOTE RANDOMNESS)
    double M12 = (Kaon1 + vec_array[r]).M();     double M13 = (Kaon1 + vec_array[1-r]).M();
    
    double PT = (Kaon1 + Kaon2 + Kaon3).Pt();
    double Bmass = (Kaon1 + Kaon2 + Kaon3).M();
    
    if(Bmass < B_m + 50 && Bmass > B_m - 50 && PT > 1700) { // B Pt and Mass cuts
    
        if( (M12 < D0m - 30. || M12 > D0m + 30.) && (M13 < D0m - 30. || M13 > D0m + 30.) ){ // D0 exclusion
            
            if(M12 > M13){
                if(H1_Charge == -1) {
                    h_Mlowplus->Fill(M13*M13/1e6);   h_Mhighplus->Fill(M12*M12/1e6);
                    h_Bplus_sym->Fill(M13*M13/1e6,M12*M12/1e6); 
                    whole->Fill(M13*M13/1e6,M12*M12/1e6); 
                    if(M12*M12 < 15e6) {h_Mlowplus_focused->Fill(M13*M13/1e6);}                                        
                }
                if(H1_Charge == 1) {
                    h_Mlowminus->Fill(M13*M13/1e6);   h_Mhighminus->Fill(M12*M12/1e6);
                    h_Bminus_sym->Fill(M13*M13/1e6,M12*M12/1e6); 
                    whole->Fill(M13*M13/1e6,M12*M12/1e6); 
                    if(M12*M12 < 15e6) {h_Mlowminus_focused->Fill(M13*M13/1e6);}                    
                }  
            }
            
            else{
                if(H1_Charge == -1) {
                    h_Mlowplus->Fill(M12*M12/1e6);   h_Mhighplus->Fill(M13*M13/1e6);
                    h_Bplus_sym->Fill(M12*M12/1e6,M13*M13/1e6); 
                    whole->Fill(M12*M12/1e6,M13*M13/1e6); 
                    if(M13*M13 < 15e6) {h_Mlowplus_focused->Fill(M12*M12/1e6);}                                  
                }
                if(H1_Charge == 1) {
                    h_Mlowminus->Fill(M12*M12/1e6);   h_Mhighminus->Fill(M13*M13/1e6);
                    h_Bminus_sym->Fill(M12*M12/1e6,M13*M13/1e6); 
                    whole->Fill(M12*M12/1e6,M13*M13/1e6); 
                    if(M13*M13 < 15e6) {h_Mlowminus_focused->Fill(M12*M12/1e6);}               
                }                  
            }

              
            if(H1_Charge == -1) {
                h_Bplus->Fill(M12*M12/1e6,M13*M13/1e6);
            }

            if(H1_Charge == 1) { 
                h_Bminus->Fill(M12*M12/1e6,M13*M13/1e6);
            }
        }
    }
}

// %%
auto c1 = new TCanvas("c1","c1",1000,400);
c1->Divide(2,1);

// h_Bplus->SetStats(1);
// h_Bplus->SetStats(1);

c1->cd(1); h_Bplus->Draw("COLZ");
c1->cd(2); h_Bminus->Draw("COLZ");
c1->Draw()

// %%
auto c1 = new TCanvas("c1","c1",1000,400);    c1->Divide(2,1);

c1->cd(1); h_Bplus_sym->Draw("text COLZ");
c1->cd(2); h_Bminus_sym->Draw("text COLZ");
c1->Draw()
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1

// %%
TCanvas *canvas = new TCanvas("Canvas","",550,350);
h_Mlowplus->Draw();
h_Mlowminus->Draw("samehist");
h_Mlowminus->SetLineColor(1);

TLegend *leg = new TLegend(0.7,0.6,0.9,0.75);
leg->AddEntry(h_Mlowplus, "B+", "l"); leg->AddEntry(h_Mlowminus, "B-", "l"); leg->Draw();
canvas->Draw()
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas

// %%
h_Mhighplus->Draw();
h_Mhighminus->Draw("samehist");
h_Mhighminus->SetLineColor(1);

TLegend *leg = new TLegend(0.7,0.6,0.9,0.75);
leg->AddEntry(h_Mhighplus, "B+", "l"); leg->AddEntry(h_Mhighminus, "B-", "l"); leg->Draw();
canvas->Draw()

// %% [markdown]
// the $Mlow^2$ variable for $Mhigh^2$ < 15 $GeV^2/c^4$ [ref](https://lhcbproject.web.cern.ch/lhcbproject/Publications/LHCbProjectPublic/LHCb-PAPER-2013-027.html)

// %%
TCanvas *canvas = new TCanvas("Canvas","",550,350);

h_Mlowplus_focused->Draw();
h_Mlowminus_focused->Draw("samehist");
h_Mlowminus_focused->SetLineColor(1);

TLegend *leg = new TLegend(0.7,0.6,0.9,0.75);
leg->AddEntry(h_Mlowplus_focused, "B+", "l"); leg->AddEntry(h_Mlowminus_focused, "B-", "l"); leg->Draw();
canvas->Draw()
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas

// %% [markdown]
// -----------------

// %% [markdown]
// # Asymmetry
//
// # <div style="text-align:center"> $A = \frac{N^- - N^+}{N^- + N^+}$ </div>
//
// # Statistical uncertainty
//
// # <div style="text-align:center"> $\sigma_A = \sqrt{ \frac{1 - A^2}{N^- + N^+} }  $ </div>
//
// The significance of the result, sigma, is found by dividing the value for asymmetry by its uncertainty. A value exceeding three sigma is considered "evidence" by particle physicists while a value of five sigma or more can be called an "observation" or "discovery"

// %% [markdown]
// #### Operating histograms

// %%
TH2F *Numerator = (TH2F*) h_Bminus_sym->Clone();
TH2F *Denominator = (TH2F*) h_Bminus_sym->Clone();
Numerator->Add(h_Bplus_sym, -1);
Denominator->Add(h_Bplus_sym, 1);

Numerator->Divide(Denominator);

TH2F *Asym = Numerator;
Asym->SetTitle("Asymmetry");
    
TCanvas *canvas = new TCanvas("Canvas","",1000,600);
Asym->SetStats(0);
Asym->Draw("text colz1");
canvas->Draw();
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas

// %% [markdown]
// #### Re-setting bin content

// %%
TH2F *Uncertainty = (TH2F*) Asym->Clone();
Uncertainty->SetTitle("Statistical uncertainty");

for (int bin=0; bin<=Asym->GetNcells(); ++bin) {
    double binAsym = Uncertainty->GetBinContent(bin);
    double binDenom = Denominator->GetBinContent(bin);
    Uncertainty->SetBinContent(bin, sqrt( (1 - binAsym*binAsym) / binDenom ));
}
    
TCanvas *canvas = new TCanvas("Canvas","",1000,600);
Uncertainty->SetStats(0);
Uncertainty->Draw("text colz");
canvas->Draw();
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas

// %%
TH2F *Significance = (TH2F*) Asym->Clone();
Significance->SetTitle("Significance");

Significance->Divide(Uncertainty);
    
TCanvas *canvas = new TCanvas("Canvas","",1000,600);
// Significance->SetStats(0);
Significance->Draw("text colz1");
canvas->Draw();
// Out:
// Warning in <TCanvas::Constructor>: Deleting canvas with same name: Canvas
